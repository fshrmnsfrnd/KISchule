# %% [markdown]
# # Polynomielle Regression
# ## Aufgabe 1
# Laden Sie erneut das california_housing Dataset aus der letzten Übung. Zerlegen Sie erneut das Dataset in x und y Daten und machen Sie anschließend wiederrum die Aufteilung in 70% Trainingsdaten und 30% Testdaten.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
dataset = fetch_california_housing()
X, y = dataset.data, dataset.target

x_train, x_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.3, random_state=42)

# %% [markdown]
# ## Aufgabe 2
# - Wenden Sie nun die Polynomielle Regression auf das Dataset an. Verwenden Sie zuerst ein Polynom 2.Grades.
# - Geben Sie im nächsten Schritt den Shape der original Daten sowie der transformierten Daten aus.
# - Wenden Sie dann auf die transformierten Daten die Lineare Regression an.
# - Vergleichen Sie den R2-Score (Erinnerung ursprünglicher R2-Score: 0.59)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

pf = PolynomialFeatures(degree=2).fit(x_train)
x_train_transformed = pf.transform(x_train)
x_test_transformed = pf.transform(x_test)
print(x_test_transformed.shape)

poly_regr = LinearRegression()
poly_regr.fit(x_train_transformed, y_train)
r2_score = poly_regr.score(x_test_transformed, y_test)
print(f"R²-Score: {r2_score:.4f}")
# Out:
# (6192, 45)
# R²-Score: 0.6534

# %% [markdown]
# ## Aufgabe 3
# Können Sie den R2-Score noch optimieren? Testen Sie ein Polynom höheren Grades. Nutzen Sie dazu GridSearch (Achtung! Rechenzeit steigt an)

# %%
from sklearn.model_selection import GridSearchCV

pf = PolynomialFeatures()

parameters = {
    "degree": [1, 2, 3, 4, 5],
}

grid_cv = GridSearchCV(pf, parameters, cv=3, n_jobs=-1)

grid_cv.fit(x_train)
print("Best Params:", grid_cv.best_params_)

best_pf = grid_cv.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 11
#       5 parameters = {
#       6     "degree": [1, 2, 3, 4, 5],
#       7 }
#       9 grid_cv = GridSearchCV(pf, parameters, cv=3, n_jobs=-1)
# ---> 11 grid_cv.fit(x_train)
#      12 print("Best Params:", grid_cv.best_params_)
#      14 best_pf = grid_cv.best_estimator_
#
# File c:\Users\Nico\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Nico\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:953, in BaseSearchCV.fit(self, X, y, **params)
#     919 """Run fit with all sets of parameters.
#     920
#     921 Parameters
#    (...)
#     950     Instance of fitted estimator.
#     951 """
#     952 estimator = self.estimator
# --> 953 scorers, refit_metric = self._get_scorers()
#     955 X, y = indexable(X, y)
#     956 params = _check_method_params(X, params=params)
#
# File c:\Users\Nico\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:850, in BaseSearchCV._get_scorers(self)
#     848     scorers = self.scoring
#     849 elif self.scoring is None or isinstance(self.scoring, str):
# --> 850     scorers = check_scoring(self.estimator, self.scoring)
#     851 else:
#     852     scorers = _check_multimetric_scoring(self.estimator, self.scoring)
#
# File c:\Users\Nico\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\Nico\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_scorer.py:1046, in check_scoring(estimator, scoring, allow_none, raise_exc)
#    1044     return None
#    1045 else:
# -> 1046     raise TypeError(
#    1047         "If no scoring is specified, the estimator passed should "
#    1048         "have a 'score' method. The estimator %r does not." % estimator
#    1049     )
#
# TypeError: If no scoring is specified, the estimator passed should have a 'score' method. The estimator PolynomialFeatures() does not.
